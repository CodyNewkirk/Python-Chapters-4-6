# %%
# File Name: Countdown.py
# Course: SDEV220
# Author: Cody Newkirk

# This program prints each value in the list [3, 2, 1, 0] using a for loop

countdown = [3, 2, 1, 0]

for number in countdown:
    print(number)
